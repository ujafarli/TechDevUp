# %%
import numpy as np
import pandas as pd

# %%
# Preprocessing Infected data
infected = pd.read_csv('time_series_covid19_confirmed_global.csv')
infected_aze = infected[infected['Country/Region'] == 'Azerbaijan']
infected_aze
# Out:
#    Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 17            NaN     Azerbaijan  40.1431  47.5769        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  3/30/20  \
# 17        0        0        0  ...      165      182      209      273
#
#     3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# 17      298     359     400     443     521     584
#
# [1 rows x 79 columns]

# %%
infected_aze = infected_aze.rename(index={17: 'infected'})
infected_aze
# Out:
#          Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# infected            NaN     Azerbaijan  40.1431  47.5769        0        0
#
#           1/24/20  1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  \
# infected        0        0        0        0  ...      165      182      209
#
#           3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# infected      273      298     359     400     443     521     584
#
# [1 rows x 79 columns]

# %%
# Preprocessing Input data
death = pd.read_csv('time_series_covid19_deaths_global.csv')
death_aze = death[death['Country/Region'] == 'Azerbaijan']
death_aze
# Out:
#    Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 17            NaN     Azerbaijan  40.1431  47.5769        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  3/30/20  \
# 17        0        0        0  ...        3        4        4        4
#
#     3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# 17        5       5       5       5       5       7
#
# [1 rows x 79 columns]

# %%
death_aze = death_aze.rename(index={17: 'death'})
death_aze
# Out:
#       Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# death            NaN     Azerbaijan  40.1431  47.5769        0        0
#
#        1/24/20  1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  \
# death        0        0        0        0  ...        3        4        4
#
#        3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# death        4        5       5       5       5       5       7
#
# [1 rows x 79 columns]

# %%
# Preprocessing Input data
recovered = pd.read_csv('time_series_covid19_recovered_global.csv')
recovered_aze = recovered[recovered['Country/Region'] == 'Azerbaijan']
recovered_aze
# Out:
#    Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 17            NaN     Azerbaijan  40.1431  47.5769        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  3/30/20  \
# 17        0        0        0  ...       15       15       15       26
#
#     3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# 17       26      26      26      32      32      32
#
# [1 rows x 79 columns]

# %%
recovered_aze = recovered_aze.rename(index={17: 'recovered'})
recovered_aze
# Out:
#           Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# recovered            NaN     Azerbaijan  40.1431  47.5769        0        0
#
#            1/24/20  1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  \
# recovered        0        0        0        0  ...       15       15       15
#
#            3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# recovered       26       26      26      26      32      32      32
#
# [1 rows x 79 columns]

# %%
result = [infected_aze, death_aze, recovered_aze]

# %%
data = pd.concat(result)
data
# Out:
#           Province/State Country/Region      Lat     Long  1/22/20  1/23/20  \
# infected             NaN     Azerbaijan  40.1431  47.5769        0        0
# death                NaN     Azerbaijan  40.1431  47.5769        0        0
# recovered            NaN     Azerbaijan  40.1431  47.5769        0        0
#
#            1/24/20  1/25/20  1/26/20  1/27/20  ...  3/27/20  3/28/20  3/29/20  \
# infected         0        0        0        0  ...      165      182      209
# death            0        0        0        0  ...        3        4        4
# recovered        0        0        0        0  ...       15       15       15
#
#            3/30/20  3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# infected       273      298     359     400     443     521     584
# death            4        5       5       5       5       5       7
# recovered       26       26      26      26      32      32      32
#
# [3 rows x 79 columns]

# %%
del data['Province/State']

# %%
del data['Lat']

# %%
del data['Long']

# %%
del data['Country/Region']

# %%
data
# Out:
#            1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# infected         0        0        0        0        0        0        0
# death            0        0        0        0        0        0        0
# recovered        0        0        0        0        0        0        0
#
#            1/29/20  1/30/20  1/31/20  ...  3/27/20  3/28/20  3/29/20  3/30/20  \
# infected         0        0        0  ...      165      182      209      273
# death            0        0        0  ...        3        4        4        4
# recovered        0        0        0  ...       15       15       15       26
#
#            3/31/20  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20
# infected       298     359     400     443     521     584
# death            5       5       5       5       5       7
# recovered       26      26      26      32      32      32
#
# [3 rows x 75 columns]

# %%
data = data.T

# %%
data
# Out:
#          infected  death  recovered
# 1/22/20         0      0          0
# 1/23/20         0      0          0
# 1/24/20         0      0          0
# 1/25/20         0      0          0
# 1/26/20         0      0          0
# ...           ...    ...        ...
# 4/1/20        359      5         26
# 4/2/20        400      5         26
# 4/3/20        443      5         32
# 4/4/20        521      5         32
# 4/5/20        584      7         32
#
# [75 rows x 3 columns]

# %%
data = data.tail(36)

# %%
# Preprocessing Input data
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
X = data.iloc[:,0]
X
# Out:
# 3/1/20       3
# 3/2/20       3
# 3/3/20       3
# 3/4/20       3
# 3/5/20       6
# 3/6/20       6
# 3/7/20       9
# 3/8/20       9
# 3/9/20       9
# 3/10/20     11
# 3/11/20     11
# 3/12/20     11
# 3/13/20     15
# 3/14/20     15
# 3/15/20     23
# 3/16/20     28
# 3/17/20     28
# 3/18/20     28
# 3/19/20     44
# 3/20/20     44
# 3/21/20     53
# 3/22/20     65
# 3/23/20     72
# 3/24/20     87
# 3/25/20     93
# 3/26/20    122
# 3/27/20    165
# 3/28/20    182
# 3/29/20    209
# 3/30/20    273
# 3/31/20    298
# 4/1/20     359
# 4/2/20     400
# 4/3/20     443
# 4/4/20     521
# 4/5/20     584
# Name: infected, dtype: int64

# %%
Y = data.iloc[:,1]
Y
# Out:
# 3/1/20     0
# 3/2/20     0
# 3/3/20     0
# 3/4/20     0
# 3/5/20     0
# 3/6/20     0
# 3/7/20     0
# 3/8/20     0
# 3/9/20     0
# 3/10/20    0
# 3/11/20    0
# 3/12/20    0
# 3/13/20    1
# 3/14/20    1
# 3/15/20    1
# 3/16/20    1
# 3/17/20    1
# 3/18/20    1
# 3/19/20    1
# 3/20/20    1
# 3/21/20    1
# 3/22/20    1
# 3/23/20    1
# 3/24/20    1
# 3/25/20    2
# 3/26/20    3
# 3/27/20    3
# 3/28/20    4
# 3/29/20    4
# 3/30/20    4
# 3/31/20    5
# 4/1/20     5
# 4/2/20     5
# 4/3/20     5
# 4/4/20     5
# 4/5/20     7
# Name: death, dtype: int64

# %%
Z = data.iloc[:,2]
Z
# Out:
# 3/1/20      0
# 3/2/20      0
# 3/3/20      0
# 3/4/20      0
# 3/5/20      0
# 3/6/20      0
# 3/7/20      0
# 3/8/20      0
# 3/9/20      0
# 3/10/20     0
# 3/11/20     3
# 3/12/20     3
# 3/13/20     3
# 3/14/20     3
# 3/15/20     6
# 3/16/20     6
# 3/17/20     6
# 3/18/20     6
# 3/19/20     6
# 3/20/20     6
# 3/21/20    11
# 3/22/20    10
# 3/23/20    10
# 3/24/20    10
# 3/25/20    10
# 3/26/20    15
# 3/27/20    15
# 3/28/20    15
# 3/29/20    15
# 3/30/20    26
# 3/31/20    26
# 4/1/20     26
# 4/2/20     26
# 4/3/20     32
# 4/4/20     32
# 4/5/20     32
# Name: recovered, dtype: int64

# %%
plt.plot(X, label = 'Infected', linewidth=3.5)
plt.plot(Y, label = 'Death', linewidth=3.5)
plt.plot(Z, label = 'Recovered', linewidth=3.5)
plt.xlabel('Time', fontsize = 24)
plt.ylabel('Number of People', fontsize=24)
plt.title('COVID-19 Cases in Azerbaijan', fontsize=24)
plt.legend(fontsize = 17)
plt.show()
